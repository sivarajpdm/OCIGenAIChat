# %% [markdown]
# <a href="https://colab.research.google.com/github/sivarajpdm/OCIGenAIChat/blob/main/numpy_and_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])

# %%
np.dot(A, B)
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
element_wise_product = A * B
# Or using np.multiply
# element_wise_product = np.multiply(A, B)
display(element_wise_product)
# Out:
# array([[ 5, 12],
#        [21, 32]])

# %%
L1=[1,2,3,4,5]
L2=[5,6,7,8,9]
L1+L2
print(type(L1))

import numpy as np
arr1 =np.array([[1,2], [3,4]])
arr2=np.array([[3,4], [5,6]])

arr1+arr2
print(arr1*arr2)
# Out:
# <class 'list'>
# [[ 3  8]
#  [15 24]]

# %%
print(L1[4])
# Out:
# 5

# %%
mat = np.array([[1, 2], [3, 4]])
mat[0, 1]     # 2
# Out:
# np.int64(2)

# %%
import pandas as pd

d = {'people':['P1','P2','P3'] , 'age' :[20,30,40]}
print(d)

df = pd.DataFrame(d)
print(df)

pd.read_excel("score_updated.xlsx")
# Out:
# {'people': ['P1', 'P2', 'P3'], 'age': [20, 30, 40]}
#   people  age
# 0     P1   20
# 1     P2   30
# 2     P3   40
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1359427901.py in <cell line: 0>()
#       7 print(df)
#       8
# ----> 9 pd.read_excel("score_updated.xlsx")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %% [markdown]
# As you can see, each element in the resulting matrix is the product of the corresponding elements from matrices `A` and `B`.
